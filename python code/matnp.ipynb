# %%
import matplotlib.pyplot as plt
import numpy as np

def exponential(n):
  return 3**n

def cubic(n):
  return n**3

def quadratic(n):
  return n**2

def loglinear(n):
  return n*np.log(n)

def linear(n):
  return n

def logarithmic(n):
  return np.log(n)

def constant(n):
  return np.ones(len(n))

n = np.arange(0, 5)

plt.plot(n, exponential(n), c='red')
plt.plot(n, cubic(n), c='orange')
plt.plot(n, quadratic(n), c='yellow')
plt.plot(n, loglinear(n), c='green')
plt.plot(n, linear(n), c='blue')
plt.plot(n, logarithmic(n), c='cyan')
plt.plot(n, constant(n), c='magenta')

plt.xlabel('Size of input (n)', fontsize=16)
plt.ylabel('Number of Operations', fontsize=16)

plt.show()
# Out:
# <ipython-input-2-34eb8375c6ba>:14: RuntimeWarning: divide by zero encountered in log
#   return n*np.log(n)
# <ipython-input-2-34eb8375c6ba>:14: RuntimeWarning: invalid value encountered in multiply
#   return n*np.log(n)
# <ipython-input-2-34eb8375c6ba>:20: RuntimeWarning: divide by zero encountered in log
#   return np.log(n)
